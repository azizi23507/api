# %%
import psycopg2
conn = psycopg2.connect(
    host="localhost",
    port=5432,
    database="pagila",
    user="postgres",
    password="shabir123"
)
cursor = conn.cursor()

# %%
cursor.execute("SELECT datname FROM pg_database;")
tables = cursor.fetchall()
print(tables)
# Out:
# [('postgres',), ('scratch',), ('template1',), ('template0',), ('northwind',), ('album',), ('world',), ('periodic_table',), ('netflix',), ('sleep_monitor',), ('fhir_observations',), ('pagila',)]

# %%
cursor.execute("SELECT table_name FROM information_schema.tables WHERE table_schema = 'public';")
tables = cursor.fetchall()
print(tables)
# Out:
# [('actor_info',), ('customer_list',), ('film_list',), ('nicer_but_slower_film_list',), ('sales_by_film_category',), ('sales_by_store',), ('staff_list',), ('payment',), ('payment_p2022_07',), ('film',), ('actor',), ('address',), ('category',), ('city',), ('country',), ('customer',), ('film_actor',), ('film_category',), ('inventory',), ('language',), ('rental',), ('staff',), ('store',), ('payment_p2022_01',), ('payment_p2022_02',), ('payment_p2022_03',), ('payment_p2022_04',), ('payment_p2022_05',), ('payment_p2022_06',)]

# %%
cursor.execute("SELECT extra_data FROM film")
extra_data_json = cursor.fetchall()
print((extra_data_json[0][0]).values())
# Out:
# dict_values([['academy', 'dinosaur'], [], {'hulu': False, 'netflix': False, 'disney_plus': False, 'amazon_prime': True}, 121289322, 174025643, {'num_reviews': 472, 'critic_score': 52, 'audience_score': 75}])

# %%
import json
python_dict = {"name": "Anna", "age": 30, "heart_rate": 72.5}
json_text = json.dumps(python_dict)   # "dumps" = dump string

print(json_text)
# Out:
# {"name": "Anna", "age": 30, "heart_rate": 72.5}
